# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("cleaned_google_playstore_data.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver Android Ver  day  month  \
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10835                               Sya9a Maroc - FR               FAMILY
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 10835     4.5       38  53000.0      5000  Free    0.0       Everyone
# 10836     5.0        4   3600.0       100  Free    0.0       Everyone
# 10837     NaN        3   9500.0      1000  Free    0.0       Everyone
# 10838     4.5      114      NaN      1000  Free    0.0     Mature 17+
# 10839     4.5   398307  19000.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated Current Ver Android Ver  day  month  \
# ...

# %%
df.sample(10)
# Out:
#                                                App            Category  \
# 2409    Cardiac diagnosis (heart rate, arrhythmia)             MEDICAL
# 775                                Pocket SAT Math           EDUCATION
# 9446   Ei Somoy & Dainik Sangbad & Statesman (PDF)  NEWS_AND_MAGAZINES
# 5472   AP Biology Prep: Practice Tests, Flashcards              FAMILY
# 3455             QR Scanner & Barcode Scanner 2018        PRODUCTIVITY
# 6211                              OnTrack Diabetes             MEDICAL
# 9893                             EU CBRNE Glossary  LIBRARIES_AND_DEMO
# 10268                    Middlesbrough FC Official              SPORTS
# 1536         How to sew & make the easiest pattern  LIBRARIES_AND_DEMO
# 870                                           H TV       ENTERTAINMENT
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 2409      4.4        8   6500.0       100  Paid  12.99       Everyone
# ...

# %%
df.shape
# Out:
# (10840, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     9373 non-null   object
#  12  Android Ver     9476 non-null   object
#  13  day             10840 non-null  int64
#  14  month           10840 non-null  int64
#  15  year            10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
df.describe()
# Out:
#             Rating       Reviews           Size      Installs         Price  \
# count  9366.000000  1.084000e+04    9145.000000  1.084000e+04  10840.000000
# mean      4.191757  4.441529e+05   21506.534062  1.546434e+07      1.027368
# std       0.515219  2.927761e+06   22596.020795  8.502936e+07     15.949703
# min       1.000000  0.000000e+00      10.000000  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01    4900.000000  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03   13000.000000  1.000000e+05      0.000000
# 75%       4.500000  5.477550e+04   30000.000000  5.000000e+06      0.000000
# max       5.000000  7.815831e+07  100000.000000  1.000000e+09    400.000000
#
#                 day         month          year
# count  10840.000000  10840.000000  10840.000000
# mean      15.609041      6.422325   2017.399723
# std        9.561621      2.578388      1.100914
# min        1.000000      1.000000   2010.000000
# ...

# %%
df.describe().T
# Out:
#             count          mean           std     min     25%       50%  \
# Rating     9366.0  4.191757e+00  5.152189e-01     1.0     4.0       4.3
# Reviews   10840.0  4.441529e+05  2.927761e+06     0.0    38.0    2094.0
# Size       9145.0  2.150653e+04  2.259602e+04    10.0  4900.0   13000.0
# Installs  10840.0  1.546434e+07  8.502936e+07     0.0  1000.0  100000.0
# Price     10840.0  1.027368e+00  1.594970e+01     0.0     0.0       0.0
# day       10840.0  1.560904e+01  9.561621e+00     1.0     6.0      16.0
# month     10840.0  6.422325e+00  2.578388e+00     1.0     5.0       7.0
# year      10840.0  2.017400e+03  1.100914e+00  2010.0  2017.0    2018.0
#
#                 75%           max
# Rating          4.5  5.000000e+00
# Reviews     54775.5  7.815831e+07
# Size        30000.0  1.000000e+05
# Installs  5000000.0  1.000000e+09
# Price           0.0  4.000000e+02
# day            24.0  3.100000e+01
# month           8.0  1.200000e+01
# year         2018.0  2.018000e+03

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'day', 'month', 'year'],
#       dtype='object')

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df[df.duplicated("App")] #lets drop duplicated in app column
# Out:
#                                       App       Category  Rating  Reviews  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2    80805
# 236                                   Box       BUSINESS     4.2   159872
# 239                    Google My Business       BUSINESS     4.4    70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4    31614
# 261             join.me - Simple Meetings       BUSINESS     4.0     6989
# ...                                   ...            ...     ...      ...
# 10714                  FarmersOnly Dating         DATING     3.0     1145
# 10719  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 10729                         FP Notebook        MEDICAL     4.5      410
# 10752      Slickdeals: Coupons & Shopping       SHOPPING     4.5    33599
# 10767                                AAFP        MEDICAL     3.8       63
#
#           Size  Installs  Type  Price Content Rating         Genres  \
# ...

# %%
df=df.drop_duplicates(subset=['App'],keep='first')

# %%
df.shape
# Out:
# (9659, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     8596 non-null   object
#  12  Android Ver     8667 non-null   object
#  13  day             9659 non-null   int64
#  14  month           9659 non-null   int64
#  15  year            9659 non-null   int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.3+ MB

# %%
numeric_feature=[feature for feature in df.columns if df[feature].dtype !='O'] #segregate the feature

# %%
categorical_feature=[feature for feature in df.columns if df[feature].dtype =='O'] #segregate the feature

# %%
numeric_feature
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
categorical_feature
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df[numeric_feature] # we successfully segregated the data
# Out:
#        Rating  Reviews     Size  Installs  Price  day  month  year
# 0         4.1      159  19000.0     10000    0.0    7      1  2018
# 1         3.9      967  14000.0    500000    0.0   15      1  2018
# 2         4.7    87510   8700.0   5000000    0.0    1      8  2018
# 3         4.5   215644  25000.0  50000000    0.0    8      6  2018
# 4         4.3      967   2800.0    100000    0.0   20      6  2018
# ...       ...      ...      ...       ...    ...  ...    ...   ...
# 10835     4.5       38  53000.0      5000    0.0   25      7  2017
# 10836     5.0        4   3600.0       100    0.0    6      7  2018
# 10837     NaN        3   9500.0      1000    0.0   20      1  2017
# 10838     4.5      114      NaN      1000    0.0   19      1  2015
# 10839     4.5   398307  19000.0  10000000    0.0   25      7  2018
#
# [9659 rows x 8 columns]

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver Android Ver  day  month  \
# ...

# %%
#value counts
df["Type"].value_counts(normalize=True)*100 #if you want to get percentile , use normalize
# Out:
# Type
# Free    92.172292
# Paid     7.827708
# Name: proportion, dtype: float64

# %%
#for each and every vaiable
for col in categorical_feature:
    print(f"{col}: {df[col].value_counts(normalize=True)*100}")
    print("==================================================")
# Out:
# App: App
# Photo Editor & Candy Camera & Grid & ScrapBook    0.010353
# Tic Tac CK                                        0.010353
# INFAMY RO                                         0.010353
# CK Call NEW                                       0.010353
# Ck Coif                                           0.010353
#                                                     ...
# Bike Race Free - Top Motorcycle Racing Games      0.010353
# Dance School Stories - Dance Dreams Come True     0.010353
# 3D Bowling                                        0.010353
# Mind Games Pro                                    0.010353
# iHoroscope - 2018 Daily Horoscope & Astrology     0.010353
# Name: proportion, Length: 9659, dtype: float64
# ...
# Category: Category
# FAMILY                 18.966767
# GAME                    9.928564
# TOOLS                   8.561963
# BUSINESS                4.348276
# MEDICAL                 4.089450
# PERSONALIZATION         3.892743
# PRODUCTIVITY            3.872036
# ...

# %%
#for univariate if numerical value , distribution plot
#if categorical value ,count plot

# %%
sns.countplot( x=df["Type"])  #univariate analysis
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
sns.countplot( x=df["Content Rating"]) #univariate analysis
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %%
# categorical columns 
plt.figure(figsize=(20, 15)) 
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.) 
category = [ 'Type', 'Content Rating'] 
for i in range(0, len(category)): 
    plt.subplot(2, 2, i+1) 
    sns.countplot(x=df[category[i]],palette="Set2") 
    plt.xlabel(category[i]) 
    plt.xticks(rotation=45) 
    plt.tight_layout()

# %%
numeric_feature
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
sns.kdeplot(df["Price"])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.kdeplot(df["Reviews"]) #right distribution skew
# Out:
# <Axes: xlabel='Reviews', ylabel='Density'>

# %%
sns.kdeplot(df["Rating"]) #left distribution skew
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
plt.figure(figsize=(15,15)) 
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.) 
for i in range(0, len(numeric_feature)): 
    plt.subplot(5, 3, i+1) 
    sns.kdeplot(x=df[numeric_feature[i]],shade=True, color='r') 
    plt.xlabel(numeric_feature[i]) 
    plt.tight_layout()

# %%
sns.distplot(df["Rating"]) #you can ty even distplot
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.histplot(df["Rating"]) #you can check even using histogam plot
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
plt.hist(df["Rating"])
plt.show()

# %%
#univariate analysis

# %%
#most popular categoy in app

# %%
df["Category"].value_counts().plot.pie(y=df["Category"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#i want top 10 category , see the solution below

# %%
df["Category"].value_counts()[:10]
# Out:
# Category
# FAMILY             1832
# GAME                959
# TOOLS               827
# BUSINESS            420
# MEDICAL             395
# PERSONALIZATION     376
# PRODUCTIVITY        374
# LIFESTYLE           369
# FINANCE             345
# SPORTS              325
# Name: count, dtype: int64

# %%
# Check the first few rows of your data
print(df['Category'].head())
# Out:
# 0    ART_AND_DESIGN
# 1    ART_AND_DESIGN
# 2    ART_AND_DESIGN
# 3    ART_AND_DESIGN
# 4    ART_AND_DESIGN
# Name: Category, dtype: object

# %%
# Create the 'category' DataFrame
category = pd.DataFrame(df['Category'].value_counts()).reset_index()
category.columns = ['Category', 'Count']
print(category.head())  # To verify the DataFrame structure
# Out:
#    Category  Count
# 0    FAMILY   1832
# 1      GAME    959
# 2     TOOLS    827
# 3  BUSINESS    420
# 4   MEDICAL    395

# %%
# Plot the top 10 categories
plt.figure(figsize=(15, 6))
sns.barplot(x='Category', y='Count', data=category[:10], palette='hls')  # Use 'data' to reference DataFrame
plt.title('Top 10 App Categories')
plt.xticks(rotation=90)
plt.show()

# %%
#which category has the largest number of installation 
#it is bi variate

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver Android Ver  day  month  \
# ...

# %%
df.groupby(["Category"])["Installs"]

# %%
df.groupby(["Category"])["Installs"].sum()
# Out:
# Category
# ART_AND_DESIGN           114338100
# AUTO_AND_VEHICLES         53130211
# BEAUTY                    27197050
# BOOKS_AND_REFERENCE     1665969576
# BUSINESS                 697164865
# COMICS                    44981150
# COMMUNICATION          11038276251
# DATING                   140926107
# EDUCATION                352952000
# ENTERTAINMENT           2113660000
# EVENTS                    15973161
# FAMILY                  4427941505
# FINANCE                  455348734
# FOOD_AND_DRINK           211798751
# GAME                   13878924415
# HEALTH_AND_FITNESS      1144022512
# HOUSE_AND_HOME            97212461
# LIBRARIES_AND_DEMO        52995910
# LIFESTYLE                503823539
# MAPS_AND_NAVIGATION      503281890
# MEDICAL                   38193177
# NEWS_AND_MAGAZINES      2369217760
# PARENTING                 31521110
# PERSONALIZATION         1532494782
# PHOTOGRAPHY             4649147655
# PRODUCTIVITY            5793091369
# ...

# %%
df.groupby(["Category"])["Installs"].sum().sort_values(ascending=False)
# Out:
# Category
# GAME                   13878924415
# COMMUNICATION          11038276251
# TOOLS                   8001771915
# PRODUCTIVITY            5793091369
# SOCIAL                  5487867902
# PHOTOGRAPHY             4649147655
# FAMILY                  4427941505
# VIDEO_PLAYERS           3926902720
# TRAVEL_AND_LOCAL        2894887146
# NEWS_AND_MAGAZINES      2369217760
# ENTERTAINMENT           2113660000
# BOOKS_AND_REFERENCE     1665969576
# PERSONALIZATION         1532494782
# SHOPPING                1400348785
# HEALTH_AND_FITNESS      1144022512
# SPORTS                  1096474498
# BUSINESS                 697164865
# LIFESTYLE                503823539
# MAPS_AND_NAVIGATION      503281890
# FINANCE                  455348734
# WEATHER                  361100520
# EDUCATION                352952000
# FOOD_AND_DRINK           211798751
# DATING                   140926107
# ART_AND_DESIGN           114338100
# HOUSE_AND_HOME            97212461
# ...

# %%
df_cat_install=df.groupby(["Category"])["Installs"].sum().sort_values(ascending=False).reset_index() #reset.index for making it in dataframe

# %%
df_cat_install
# Out:
#                Category     Installs
# 0                  GAME  13878924415
# 1         COMMUNICATION  11038276251
# 2                 TOOLS   8001771915
# 3          PRODUCTIVITY   5793091369
# 4                SOCIAL   5487867902
# 5           PHOTOGRAPHY   4649147655
# 6                FAMILY   4427941505
# 7         VIDEO_PLAYERS   3926902720
# 8      TRAVEL_AND_LOCAL   2894887146
# 9    NEWS_AND_MAGAZINES   2369217760
# 10        ENTERTAINMENT   2113660000
# 11  BOOKS_AND_REFERENCE   1665969576
# 12      PERSONALIZATION   1532494782
# 13             SHOPPING   1400348785
# 14   HEALTH_AND_FITNESS   1144022512
# 15               SPORTS   1096474498
# 16             BUSINESS    697164865
# 17            LIFESTYLE    503823539
# 18  MAPS_AND_NAVIGATION    503281890
# 19              FINANCE    455348734
# 20              WEATHER    361100520
# 21            EDUCATION    352952000
# 22       FOOD_AND_DRINK    211798751
# 23               DATING    140926107
# ...

# %%
df2=df_cat_install.head(10)

# %%
df2 #top 10 category which has largest number of installation
# Out:
#              Category     Installs
# 0                GAME  13878924415
# 1       COMMUNICATION  11038276251
# 2               TOOLS   8001771915
# 3        PRODUCTIVITY   5793091369
# 4              SOCIAL   5487867902
# 5         PHOTOGRAPHY   4649147655
# 6              FAMILY   4427941505
# 7       VIDEO_PLAYERS   3926902720
# 8    TRAVEL_AND_LOCAL   2894887146
# 9  NEWS_AND_MAGAZINES   2369217760

# %%
sns.barplot(x="Installs",y="Category",data=df2)
# Out:
# <Axes: xlabel='Installs', ylabel='Category'>

# %%
#in beautifying way , other way to plot
plt.figure(figsize = (14,10)) 
sns.set_context("talk") 
sns.set_style("darkgrid") 
ax = sns.barplot(x = 'Installs' , y = 'Category' , data = df2 ) 
ax.set_xlabel('No. of Installations in Billions') 
ax.set_ylabel('') 
ax.set_title("Most Popular Categories in Play Store", size = 20)
# Out:
# Text(0.5, 1.0, 'Most Popular Categories in Play Store')

# %%
### What are the Top 5 most installed Apps in Each popular Categories ?? 
#it is multivariate

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver Android Ver  day  month  \
# ...

# %%
df.groupby(["Category","App"])["Installs"]

# %%
df.groupby(["Category","App"])["Installs"].sum()
# Out:
# Category        App
# ART_AND_DESIGN  350 Diy Room Decor Ideas                                                                10000
#                 3D Color Pixel by Number - Sandbox Art Coloring                                        100000
#                 AJ Styles HD Wallpapers                                                                  5000
#                 AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper                                        1000
#                 Ai illustrator viewer                                                                  100000
#                                                                                                        ...
# WEATHER         Yahoo Weather                                                                        10000000
#                 Yahoo! Weather for SH Forecast for understanding the approach of rain clouds Free     1000000
# ...

# %%
df.groupby(["Category","App"])["Installs"].sum().reset_index()
# Out:
#             Category                                                App  \
# 0     ART_AND_DESIGN                           350 Diy Room Decor Ideas
# 1     ART_AND_DESIGN    3D Color Pixel by Number - Sandbox Art Coloring
# 2     ART_AND_DESIGN                            AJ Styles HD Wallpapers
# 3     ART_AND_DESIGN  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper
# 4     ART_AND_DESIGN                              Ai illustrator viewer
# ...              ...                                                ...
# 9654         WEATHER                                      Yahoo Weather
# 9655         WEATHER  Yahoo! Weather for SH Forecast for understandi...
# 9656         WEATHER                                     Yandex.Weather
# 9657         WEATHER                         weather - weather forecast
# 9658         WEATHER                     wetter.com - Weather and Radar
#
#       Installs
# 0        10000
# 1       100000
# 2         5000
# 3         1000
# 4       100000
# ...

# %%
dfa=df.groupby(["Category","App"])["Installs"].sum().sort_values(ascending=False).reset_index()

# %%
dfa
# Out:
#                 Category                            App    Installs
# 0       TRAVEL_AND_LOCAL             Google Street View  1000000000
# 1     NEWS_AND_MAGAZINES                    Google News  1000000000
# 2          COMMUNICATION  Skype - free IM & video calls  1000000000
# 3          VIDEO_PLAYERS                        YouTube  1000000000
# 4          COMMUNICATION             WhatsApp Messenger  1000000000
# ...                  ...                            ...         ...
# 9654    TRAVEL_AND_LOCAL       EG | Explore Folegandros           0
# 9655             MEDICAL                   EP Cook Book           0
# 9656             FINANCE                    Eu sou Rico           0
# 9657              FAMILY     Ain Arabic Kids Alif Ba ta           0
# 9658  NEWS_AND_MAGAZINES              Sweden Newspapers           0
#
# [9659 rows x 3 columns]

# %%
dfa[dfa.Category=="GAME"][:5] #top 5 application
# Out:
#    Category               App    Installs
# 17     GAME    Subway Surfers  1000000000
# 22     GAME  Candy Crush Saga   500000000
# 28     GAME               Pou   500000000
# 30     GAME      Temple Run 2   500000000
# 36     GAME    My Talking Tom   500000000

# %%
dfa[dfa.Category=="PRODUCTIVITY"][:5]
# Out:
#         Category              App    Installs
# 18  PRODUCTIVITY     Google Drive  1000000000
# 38  PRODUCTIVITY   Microsoft Word   500000000
# 39  PRODUCTIVITY  Google Calendar   500000000
# 40  PRODUCTIVITY          Dropbox   500000000
# 41  PRODUCTIVITY      Cloud Print   500000000

# %%
dfa[dfa.Category=="FAMILY"][:5]
# Out:
#     Category                            App   Installs
# 49    FAMILY               Tom Loves Angela  100000000
# 81    FAMILY              Talking Tom Cat 2  100000000
# 95    FAMILY  Bitmoji – Your Personal Emoji  100000000
# 103   FAMILY                Talking Tom Cat  100000000
# 105   FAMILY         Talking Tom & Ben News  100000000

# %%
apps = ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'SOCIAL' ] 
sns.set_context("poster") 
sns.set_style("darkgrid") 
plt.figure(figsize=(40,30)) 
for i,app in enumerate(apps): 
    df2 = dfa[dfa.Category == app] 
    df3 = df2.head(5) 
    plt.subplot(4,2,i+1) #4,2 size of figure , i+! no of plot
    sns.barplot(data= df3,x= 'Installs' ,y='App' ) 
    plt.xlabel('Installation in Millions') 
    plt.ylabel('') 
    plt.title(app,size = 20) 
plt.tight_layout() 
plt.subplots_adjust(hspace= .3) 
plt.show()

# %%
#how many apps are there in google play store which get 5 ratings 
#bi variate

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver Android Ver  day  month  \
# ...

# %%
df.groupby(["App"])["Rating"]

# %%
dfa1=df.groupby(["App"])["Rating"].sum().sort_values(ascending=False).reset_index()

# %%
dfa1
# Out:
#                                                    App  Rating
# 0                            Comunidad De Fe Minitries     5.0
# 1                                      Tablet Reminder     5.0
# 2                                Noticias FC Barcelona     5.0
# 3     Superheroes, Marvel, DC, Comics, TV, Movies News     5.0
# 4                    DC N COMPANY ENTERTAINMENT RADIO!     5.0
# ...                                                ...     ...
# 9654                              DK Childcare Centers     0.0
# 9655                         Pediatric Emergency Guide     0.0
# 9656                                     Pekalongan CJ     0.0
# 9657                        Penn State Health OnDemand     0.0
# 9658              "i DT" Fútbol. Todos Somos Técnicos.     0.0
#
# [9659 rows x 2 columns]

# %%
dfa1[dfa1.Rating==5.0]
# Out:
#                                                   App  Rating
# 0                           Comunidad De Fe Minitries     5.0
# 1                                     Tablet Reminder     5.0
# 2                               Noticias FC Barcelona     5.0
# 3    Superheroes, Marvel, DC, Comics, TV, Movies News     5.0
# 4                   DC N COMPANY ENTERTAINMENT RADIO!     5.0
# ..                                                ...     ...
# 266                     American Girls Mobile Numbers     5.0
# 267                                         daskal.eu     5.0
# 268                         Free coupons and vouchers     5.0
# 269                                      Bk Usha behn     5.0
# 270                           Asha Ek Hope - ALS/ MND     5.0
#
# [271 rows x 2 columns]

# %%
rating2 = df.groupby(['Category','Installs', 'App'])['Rating'].sum().sort_values(ascending = False).reset_index()

# %%
rating2
# Out:
#             Category  Installs  \
# 0             FAMILY      1000
# 1             DATING       100
# 2             FAMILY        10
# 3             DATING       500
# 4            MEDICAL         5
# ...              ...       ...
# 9654           TOOLS       100
# 9655           TOOLS       100
# 9656        BUSINESS       100
# 9657           TOOLS       100
# 9658  ART_AND_DESIGN         0
#
#                                                    App  Rating
# 0                          CS & IT Interview Questions     5.0
# 1                              Online Girls Chat Group     5.0
# 2                                        Chronolink DX     5.0
# 3                                Spine- The dating app     5.0
# 4                                    Clinic Doctor EHr     5.0
# ...                                                ...     ...
# 9654                                         CG Wizard     0.0
# 9655  CG 3D Model Viewer: view 3D models interactively     0.0
# ...

# %%
plt.figure(figsize=(20,20))
sns.scatterplot(data=df, y="Category", x="Price")
# Out:
# <Axes: xlabel='Price', ylabel='Category'>

# %%
#which categoy app users are reviewing the most ?

# %%
 df.groupby(['Category','App'])["Reviews"].sum().reset_index()
# Out:
#             Category                                                App  \
# 0     ART_AND_DESIGN                           350 Diy Room Decor Ideas
# 1     ART_AND_DESIGN    3D Color Pixel by Number - Sandbox Art Coloring
# 2     ART_AND_DESIGN                            AJ Styles HD Wallpapers
# 3     ART_AND_DESIGN  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper
# 4     ART_AND_DESIGN                              Ai illustrator viewer
# ...              ...                                                ...
# 9654         WEATHER                                      Yahoo Weather
# 9655         WEATHER  Yahoo! Weather for SH Forecast for understandi...
# 9656         WEATHER                                     Yandex.Weather
# 9657         WEATHER                         weather - weather forecast
# 9658         WEATHER                     wetter.com - Weather and Radar
#
#       Reviews
# 0          27
# 1        1518
# 2          48
# 3          18
# 4         486
# ...

# %%
df.groupby("Category").agg({"Installs":"sum","Reviews":"sum"}).reset_index()
# Out:
#                Category     Installs    Reviews
# 0        ART_AND_DESIGN    114338100    1419203
# 1     AUTO_AND_VEHICLES     53130211    1163666
# 2                BEAUTY     27197050     396240
# 3   BOOKS_AND_REFERENCE   1665969576   16721314
# 4              BUSINESS    697164865    9890245
# 5                COMICS     44981150    2342071
# 6         COMMUNICATION  11038276251  285811368
# 7                DATING    140926107    3623544
# 8             EDUCATION    352952000   13364148
# 9         ENTERTAINMENT   2113660000   34762650
# 10               EVENTS     15973161     161018
# 11               FAMILY   4427941505  143825488
# 12              FINANCE    455348734   12662106
# 13       FOOD_AND_DRINK    211798751    6325028
# 14                 GAME  13878924415  622298709
# 15   HEALTH_AND_FITNESS   1144022512   21361355
# 16       HOUSE_AND_HOME     97212461    1929847
# 17   LIBRARIES_AND_DEMO     52995910     906831
# 18            LIFESTYLE    503823539   11832671
# ...

# %%
df.groupby('Type').agg({'Installs':sum}).plot.pie(y='Installs')
# Out:
# <Axes: ylabel='Installs'>

# %%
df.value_counts('Type').plot.pie(y='Type')
# Out:
# <Axes: ylabel='count'>

# %%
fig, ax = plt.subplots(1,2,figsize=(20,7))
df.value_counts('Type').plot.pie(y='Type',startangle=90, explode=(0.2,0), title='Percentage of the Free App and Paid App', legend=False, autopct='%.2f', ax=ax[0])
ax[0].set(ylabel='Type of Apps')
df.groupby('Type').agg({'Installs':sum}).plot.pie(y='Installs', startangle=90, explode=(0.2,0), title='Percentage of Installs Number for Free App and Paid App', legend=False, autopct='%.2f', ax=ax[1])
# Out:
# <Axes: title={'center': 'Percentage of Installs Number for Free App and Paid App'}, ylabel='Installs'>

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver Android Ver  day  month  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x="Installs",y="Rating",data=df)
plt.xticks(size=15,rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x="Category",y="Rating",data=df)
plt.xticks(size=15,rotation=90)
plt.show()

# %%
#Which Category are of largest size ??

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'day', 'month', 'year'],
#       dtype='object')

# %%
plt.figure(figsize=(15, 15))
plt.xticks(rotation=90)
sns.barplot(x='Category', y='Size', data=df)  # Pass 'x' and 'y' as keyword arguments
plt.show()

# %%
plt.subplots(figsize=(20,10))
freq= pd.Series()
freq=df['year'].value_counts()
freq.plot()
plt.xlabel("Dates")
plt.ylabel("Number of updates")
plt.title("Time series plot of Last Updates")
# Out:
# Text(0.5, 1.0, 'Time series plot of Last Updates')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver Android Ver  day  month  \
# ...

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='Rating',data = df,palette="Set1_r")
plt.xticks(rotation =90)
plt.title('Countplot for ratings')             
plt.show()
